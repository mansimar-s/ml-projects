# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.decomposition import PCA

# %%
train = pd.read_csv("cleaned_train.csv", index_col=0)

# %%
target = train.Survived

# %%
train.drop("Survived", axis=1, inplace=True)

# %%
train.drop("PassengerId", axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)

# %%
pca = PCA(n_components=2)

# %%
pca.fit(scaled_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(scaled_train)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0], x_pca[:,1], c=target, cmap="plasma")
plt.xlabel("First Principal Component")
plt.ylabel("Second Principal Component")
# Out:
# Text(0,0.5,'Second Principal Component')

# %%
df_comp = pd.DataFrame(pca.components_, columns=train.columns)

# %%
df_comp.head()
# Out:
#      Pclass       Age     SibSp     Parch      Fare      male         Q  \
# 0 -0.600353  0.274815  0.129207  0.238424  0.602495 -0.265958 -0.232976
# 1  0.270578 -0.487153  0.555423  0.543998  0.051523 -0.280927  0.036973
#
#           S
# 0 -0.050005
# 1  0.045818

# %%
plt.figsize = (10,8)
sns.heatmap(df_comp, cmap="plasma")
